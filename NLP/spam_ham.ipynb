# %% [markdown]
# # SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
spam = pd.read_csv('https://cdn.upgrad.com/UpGrad/temp/a4964625-11c7-4043-adc5-23c0160b2ac1/SMSSpamCollection.txt', sep='\t', names=['label', 'message'])
spam.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:5])
# Out:
# [(['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18'], 'spam'), (['dun', 'say', 'early', 'hor', '...', 'already', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'usf', 'live', 'around', 'though'], 'ham')]

# %% [markdown]
# ### Preparing to create features

# %%
def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 8393

# %% [markdown]
# ### Preparing to create a train and test set

# %%
sliceIndex = int((len(messages_set)*.8))

# %%
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
# Out:
# 4457

# %%
len(test_messages)
# Out:
# 1115

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contains(jurong)': False, 'contains(point)': False, 'contains(crazy..)': False, 'contains(available)': False, 'contains(bugis)': False, 'contains(great)': False, 'contains(world)': False, 'contains(buffet)': False, 'contains(...)': False, 'contains(cine)': False, 'contains(get)': False, 'contains(amore)': False, 'contains(wat)': False, 'contains(lar)': False, 'contains(joke)': False, 'contains(wif)': False, 'contains(oni)': False, 'contains(free)': False, 'contains(entry)': False, 'contains(wkly)': False, 'contains(comp)': False, 'contains(win)': False, 'contains(cup)': False, 'contains(final)': False, 'contains(tkts)': False, 'contains(21st)': False, 'contains(may)': False, 'contains(2005.)': False, 'contains(text)': False, 'contains(87121)': False, 'contains(receive)': False, 'contains(question)': False, 'contains(std)': False, 'contains(txt)': False, 'contains(rate)': False, 'contains(apply)': False, 'contains(08452810075over18)': False, 'contains(dun)': False, 'contains(say)': False, 'contains(early)': False, 'contains(hor)': False, 'contains(already)': False, 'contains(nah)': False, "contains(n't)": False, 'contains(think)': False, 'contains(usf)': False, 'contains(live)': False, 'contains(around)': False, 'contains(though)': False, 'contains(freemsg)': False, 'contains(hey)': False, 'contains(darling)': False, 'contains(week)': False, 'contains(word)': False, 'contains(back)': False, 'contains(like)': False, 'contains(fun)': False, 'contains(still)': False, 'contains(xxx)': False, 'contains(chgs)': False, 'contains(send)': False, 'contains(£1.50)': False, 'contains(rcv)': False, 'contains(even)': False, 'contains(brother)': False, 'contains(speak)': False, 'contains(treat)': False, 'contains(aid)': False, 'contains(patent)': False, 'contains(per)': False, 'contains(request)': False, "contains('melle)": False, 'contains(melle)': False, 'contains(oru)': False, 'contains(minnaminunginte)': False, 'contains(nurungu)': False, 'contains(vettam)': False, 'contains(set)': False, 'contains(callertune)': False, 'contains(callers)': False, 'contains(press)': False, 'contains(copy)': False, 'contains(friends)': False, 'contains(winner)': False, 'contains(value)': False, 'contains(network)': False, 'contains(customer)': False, 'contains(select)': False, 'contains(receivea)': False, 'contains(£900)': False, 'contains(prize)': False, 'contains(reward)': False, 'contains(claim)': False, 'contains(call)': False, 'contains(09061701461.)': False, 'contains(code)': False, 'contains(kl341)': False, 'contains(valid)': False, 'contains(hours)': False, 'contains(mobile)': False, 'contains(months)': False, 'contains(entitle)': False, 'contains(update)': False, 'contains(latest)': False, 'contains(colour)': False, 'contains(mobiles)': False, 'contains(camera)': False, 'contains(08002986030)': False, 'contains(gon)': False, 'contains(home)': False, 'contains(soon)': False, 'contains(want)': False, 'contains(talk)': False, 'contains(stuff)': True, 'contains(anymore)': False, 'contains(tonight)': False, "contains('ve)": False, 'contains(cry)': False, 'contains(enough)': False, 'contains(today)': False, 'contains(six)': False, 'contains(chance)': False, 'contains(cash)': False, 'contains(100)': False, 'contains(20,000)': False, 'contains(pound)': False, 'contains(csh11)': False, 'contains(87575.)': False, 'contains(cost)': False, 'contains(150p/day)': False, 'contains(6days)': False, 'contains(16+)': False, 'contains(tsandcs)': False, 'contains(reply)': False, 'contains(info)': False, 'contains(urgent)': False, 'contains(membership)': False, 'contains(£100,000)': False, 'contains(jackpot)': False, 'contains(81010)': False, 'contains(www.dbuk.net)': False, 'contains(lccltd)': False, 'contains(pobox)': False, 'contains(4403ldnw1a7rw18)': False, 'contains(search)': False, 'contains(right)': False, 'contains(thank)': False, 'contains(breather)': False, 'contains(promise)': False, 'contains(wont)': False, 'contains(take)': False, 'contains(help)': Fal ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  4457
# Test set size :  1115

# %% [markdown]
# ### Training:

# %%
spam_classifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation:

# %%
print(nltk.classify.accuracy(spam_classifier, training_set))
# Out:
# 0.9921471842046219

# %%
print(nltk.classify.accuracy(spam_classifier, testing_set))

# %%
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spam_classifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
print(spam_classifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#          contains(award) = True             spam : ham    =    189.9 : 1.0
#         contains(urgent) = True             spam : ham    =     96.7 : 1.0
#          contains(await) = True             spam : ham    =     96.1 : 1.0
#           contains(rate) = True             spam : ham    =     87.1 : 1.0
#       contains(delivery) = True             spam : ham    =     87.1 : 1.0
#           contains(code) = True             spam : ham    =     87.1 : 1.0
#        contains(service) = True             spam : ham    =     85.6 : 1.0
#          contains(nokia) = True             spam : ham    =     81.8 : 1.0
#        contains(private) = True             spam : ham    =     73.7 : 1.0
#       contains(landline) = True             spam : ham    =     73.7 : 1.0
#           contains(club) = True             spam : ham    =     69.2 : 1.0
#            contains(txt) = True             spam : ham    =     66.7 : 1.0
#      contains(statement) = True             spam : ham    =     64.8 : 1.0
#         contains(camera) = True             spam : ham    =     60.3 : 1.0
#           contains(land) = True             spam : ham    =     60.3 : 1.0
#          contains(video) = True             spam : ham    =     54.9 : 1.0
#         contains(select) = True             spam : ham    =     54.9 : 1.0
#         contains(orange) = True             spam : ham    =     52.3 : 1.0
#         contains(caller) = True             spam : ham    =     51.4 : 1.0
#            contains(box) = True             spam : ham    =     50.7 : 1.0
#        contains(network) = True             spam : ham    =     48.8 : 1.0
#         contains(mobile) = True             spam : ham    =     44.2 : 1.0
#        contains(attempt) = True             spam : ham    =     44.2 : 1.0
#         contains(latest) = True             spam : ham    =     41.2 : 1.0
#          contains(final) = True             spam : ham    =     38.9 : 1.0
#        contains(auction) = True             spam : ham    =     38.0 : 1.0
# contains(congratulations) = True             spam : ham    =     38.0 : 1.0
#            contains(del) = True             spam : ham    =     38.0 : 1.0
#           contains(quiz) = True             spam : ham    =     38.0 : 1.0
#           contains(draw) = True             spam : ham    =     38.0 : 1.0
#       contains(customer) = True             spam : ham    =     37.1 : 1.0
#           contains(info) = True             spam : ham    =     36.2 : 1.0
#          contains(music) = True             spam : ham    =     36.2 : 1.0
#           contains(comp) = True             spam : ham    =     33.5 : 1.0
#         contains(reveal) = True             spam : ham    =     33.5 : 1.0
#        contains(contact) = True             spam : ham    =     32.8 : 1.0
#            contains(per) = True             spam : ham    =     31.7 : 1.0
#         contains(colour) = True             spam : ham    =     30.8 : 1.0
#           contains(line) = True             spam : ham    =     29.4 : 1.0
#         contains(player) = True             spam : ham    =     29.0 : 1.0
#         contains(reward) = True             spam : ham    =     29.0 : 1.0
#        contains(england) = True             spam : ham    =     29.0 : 1.0
#         contains(direct) = True             spam : ham    =     28.1 : 1.0
#          contains(offer) = True             spam : ham    =     26.4 : 1.0
#          contains(pound) = True             spam : ham    =     26.1 : 1.0
#           contains(cash) = True             spam : ham    =     25.5 : 1.0
#            contains(gay) = True             spam : ham    =     24.6 : 1.0
#        contains(receive) = True             spam : ham    =     23.7 : 1.0
#           contains(chat) = True             spam : ham    =     23.6 : 1.0
#            contains(win) = True             spam : ham    =     20.1 : 1.0
# None

# %% [markdown]
# ### Save the model to disk:

# %%
import pickle
f = open('spam_or_ham.pickle', 'wb')
pickle.dump(spam_classifier, f)
print('Classifier sotred at: ', f.name)
f.close()
# Out:
# Classifier sotred at:  spam_or_ham.pickle
