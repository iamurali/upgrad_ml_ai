# %%
import numpy as np
import collections
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### States tracked

# %%
with open('States_tracked.pkl', 'rb') as handle:
    States_track = pickle.load(handle)

# %%
print(len(States_track))
# Out:
# 7

# %%
for key, value in States_track.items():
    for k,v in value.items():
        print(len(v))
# Out:
# 7500
# 7500
# 7500
# 7500
# 7500
# 7500
# 7500

# %%
xaxis = np.asarray(range(0, len(States_track[(30,3)][30])))
#print(type(xaxis))

plt.figure(0, figsize=(16,7))
plt.subplot(241)
plt.title('state=(15,mon) action=12')
plt.plot(xaxis,np.asarray(States_track[(15,0)][12]))
plt.subplot(242)
plt.title('state=(25,tue) action=25')
plt.plot(xaxis,np.asarray(States_track[(25,1)][25]))
plt.subplot(243)
plt.title('state=(20,wed) action=10')
plt.plot(xaxis,np.asarray(States_track[(20,2)][10]))
plt.subplot(244)
plt.title('state=(30,thu) action=30')
plt.plot(xaxis,np.asarray(States_track[(30,3)][30]))
plt.subplot(245)
plt.title('state=(35,fri) action=15')
plt.plot(xaxis,np.asarray(States_track[(35,4)][15]))
plt.subplot(246)
plt.title('state=(10,sat) action=18')
plt.plot(xaxis,np.asarray(States_track[(10,5)][18]))
plt.subplot(247)
plt.title('state=(50,sun) action=10')
plt.plot(xaxis,np.asarray(States_track[(50,6)][10]))
plt.show()

# %%
xaxis = np.asarray(range(0, 1000))
#print(type(xaxis))

plt.figure(0, figsize=(16,7))
plt.subplot(241)
plt.title('state=(15,mon) action=12')
plt.plot(xaxis,np.asarray(States_track[(15,0)][12][-1000:]))
plt.subplot(242)
plt.title('state=(25,tue) action=25')
plt.plot(xaxis,np.asarray(States_track[(25,1)][25][-1000:]))
plt.subplot(243)
plt.title('state=(20,wed) action=10')
plt.plot(xaxis,np.asarray(States_track[(20,2)][10][-1000:]))
plt.subplot(244)
plt.title('state=(30,thu) action=30')
plt.plot(xaxis,np.asarray(States_track[(30,3)][30][-1000:]))
plt.subplot(245)
plt.title('state=(35,fri) action=15')
plt.plot(xaxis,np.asarray(States_track[(35,4)][15][-1000:]))
plt.subplot(246)
plt.title('state=(10,sat) action=18')
plt.plot(xaxis,np.asarray(States_track[(10,5)][18][-1000:]))
plt.subplot(247)
plt.title('state=(50,sun) action=10')
plt.plot(xaxis,np.asarray(States_track[(50,6)][10][-1000:]))
plt.show()

# %%
xaxis = np.asarray(range(0, 3000))

plt.figure(0, figsize=(10,5))

plt.plot(xaxis,np.asarray(States_track[(25,1)][25][-3000:]))
plt.show()

# %%
xaxis = np.asarray(range(0, 3000))

plt.figure(0, figsize=(10,5))

plt.plot(xaxis,np.asarray(States_track[(20,2)][10][-3000:]))
plt.show()

# %%
xaxis = np.asarray(range(0, 3000))

plt.figure(0, figsize=(10,5))

plt.plot(xaxis,np.asarray(States_track[(30,3)][30][-3000:]))
plt.show()

# %%
xaxis = np.asarray(range(0, 3000))

plt.figure(0, figsize=(10,5))

plt.plot(xaxis,np.asarray(States_track[(50,6)][10][-3000:]))
plt.show()
