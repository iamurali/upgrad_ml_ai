# %% [markdown]
# ### Decision tree classifier to determine heart disease

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
disease_data = pd.read_csv('https://cdn.upgrad.com/UpGrad/temp/8a83be2b-f233-4fff-a974-011341adf3a4/heart.csv')
disease_data.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease  Unnamed: 14
# 0              2          NaN
# ...

# %%
disease_data.describe()
# Out:
#               age         sex   pain type          BP  cholestrol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333    0.677778    3.174074  131.344444  249.659259    0.148148
# std      9.109067    0.468195    0.950090   17.861608   51.686237    0.355906
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000    0.000000
# 50%     55.000000    1.000000    3.000000  130.000000  245.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  280.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#        resting ecg  max heart rate  exercise angina  ST depression  \
# count   270.000000      270.000000       270.000000      270.00000
# mean      1.022222      149.677778         0.329630        1.05000
# ...

# %%
disease_data.drop(axis=1, columns=['Unnamed: 14'], inplace=True)
disease_data.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal  \
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3
#
#    heart disease
# 0              2
# 1              1
# 2              2
# ...

# %%
y[y==2].shape
# Out:
# (120,)

# %%
x = disease_data.drop(columns=['heart disease'])
y = disease_data['heart disease']
x.head()
# Out:
#    age  sex  pain type   BP  cholestrol  fbs  resting ecg  max heart rate  \
# 0   70    1          4  130         322    0            2             109
# 1   67    0          3  115         564    0            2             160
# 2   57    1          2  124         261    0            0             141
# 3   64    1          4  128         263    0            0             105
# 4   74    0          2  120         269    0            2             121
#
#    exercise angina  ST depression  ST slope  flouroscopy coloured  thal
# 0                0            2.4         2                     3     3
# 1                0            1.6         2                     0     7
# 2                0            0.3         1                     0     7
# 3                1            0.2         2                     1     7
# 4                1            0.2         1                     1     3

# %%
x.columns
# Out:
# Index(['age', 'sex', 'pain type', 'BP', 'cholestrol', 'fbs', 'resting ecg',
#        'max heart rate', 'exercise angina', 'ST depression', 'ST slope',
#        'flouroscopy coloured', 'thal'],
#       dtype='object')

# %%
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10)

# %%
from sklearn.tree import DecisionTreeClassifier
help(DecisionTreeClassifier)
# Out:
# Help on class DecisionTreeClassifier in module sklearn.tree.tree:
#
# class DecisionTreeClassifier(BaseDecisionTree, sklearn.base.ClassifierMixin)
#  |  DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, class_weight=None, presort=False)
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : string, optional (default="gini")
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "entropy" for the information gain.
#  |
#  |  splitter : string, optional (default="best")
#  |      The strategy used to choose the split at each node. Supported
#  |      strategies are "best" to choose the best split and "random" to choose
# ...

# %%
dt_classifier = DecisionTreeClassifier(max_depth=3)

# %%
dt_classifier.fit(x, y)
y_pred = dt_classifier.predict(x_test)

# %%
dt_classifier.feature_importances_
# Out:
# array([0.        , 0.        , 0.1134196 , 0.02803092, 0.        ,
#        0.        , 0.        , 0.        , 0.08219249, 0.03567024,
#        0.        , 0.25506118, 0.48562558])

# %%
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
confusion_matrix(y_pred=y_pred, y_true=y_test)
# Out:
# array([[35,  3],
#        [ 9, 34]])

# %%
metrics.accuracy_score(y_pred=y_pred, y_true=y_test)
# Out:
# 0.8518518518518519

# %% [markdown]
# ### Tree visualisation:

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz
import pydotplus, graphviz

# %%
dot_data = StringIO()
export_graphviz(dt_classifier,
                out_file=dot_data,
                feature_names=list(x.columns[0:]),
                filledf=True,
                rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_pdf("dt_heartdisease.pdf")
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# '/Users/mural.kummitha/work/UPGRAD/TreeModels'
