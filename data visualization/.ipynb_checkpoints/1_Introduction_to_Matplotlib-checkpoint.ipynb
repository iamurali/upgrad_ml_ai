# %%
# imprting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# basic plotting of matplotlib
x = np.linspace(5, 100, 100)
y = np.linspace(5, 100, 100)

plt.plot(x,y)
plt.show()

plt.plot([1, 4, 6, 8], [3, 8, 3, 5])
plt.show()

# %%
# Plot with min, max range
x = np.linspace(5, 100, 100)
y = np.linspace(10, 1000, 100)
plt.plot(x, y)

# x and y labels, and title
plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("Ohm's Law")

plt.xlim([20, 80])
plt.ylim(200, 800)
plt.show()

# %%
# plot with different arguments
y = x*2
plt.plot(x, y, 'b+')

plt.xlabel("Current")
plt.ylabel("Voltage")
plt.title("Ohm's Law")
plt.show()

# %%
# subplot with x, y, x, y**2
x = np.linspace(0, 5, 10)
y = np.linspace(3, 6, 10)

plt.plot(x, y, 'r-', x, y**2, 'b+', x, y**3, 'g^')
plt.show()

# %%
# subplot for 2*2 matrix
x = np.linspace(1, 10, 100)
y = np.log(x)

plt.figure(1)

plt.subplot(121)
plt.title(' y = log(x)')
plt.plot(x, y)

plt.subplot(122)
plt.title('y=log(x2)')
plt.plot(x, y**2)
plt.show()

# %%
# read market fact
# Order_Quantity boxplot
# sales boxplot

# sales subplot with logerthemic
market_data = pd.read_csv('./global_sales_data/market_fact.csv')
market_data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
#histogram sales
# apply logthermic
plt.plot(market_data['Sales'])
plt.show()

plt.boxplot(market_data['Sales'])
plt.show()

market_data['Sales'].describe()
# Out:
# count     8399.000000
# mean      1775.878179
# std       3585.050525
# min          2.240000
# 25%        143.195000
# 50%        449.420000
# 75%       1709.320000
# max      89061.050000
# Name: Sales, dtype: float64

# %%
# scattered plot Sales vs Profit
plt.subplot(1, 2, 1)
plt.boxplot(market_data['Sales'])


# log scale subplot
plt.subplot(1, 2, 2)
plt.boxplot(market_data['Sales'])
plt.yscale('log')
plt.show()

# %%
plt.scatter(market_data['Sales'], market_data['Profit'])
plt.show()

# %%
plt.hist(market_data['Sales'])
plt.yscale('log')
plt.show()
